# %%
import numpy as np 
import pandas as pd
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import Dropout
from sklearn.metrics import classification_report
from keras.callbacks import EarlyStopping

# %%
#df = pd.read_csv("dataset/ask_play_station_preprocessed.csv")
df = pd.read_csv("dataset/mixed_data_preprocessed_fixed.csv")
df.dropna(inplace = True)
df
# Out:
#                                                  Company  \
# 0      @115820 I'm sorry we've let you down! Without ...
# 1      @115820 We'd like to take a further look into ...
# 2      @115822 I am unable to affect your account via...
# 3      @115826 I'm sorry for the wait. You'll receive...
# 4                  @115827 Thanks for your patience. ^KM
# ...                                                  ...
# 18663  @157688 I'm reaching out to this location's le...
# 18664  @157689 Sorry for the trouble. What location w...
# 18665  @157689 I'm sharing your concerns with their l...
# 18666  @157690 I'd be disappointed too. Let a manager...
# 18667  @157692 Yay! I'll share some love with Abdulla...
#
#                                                     User
# 0      Way to drop the ball on customer service @1158...
# 1      @AmazonHelp 3 different people have given 3 di...
# 2      @115823 I want my amazon payments account CLOS...
# 3      @115828 How about you guys figure out my Xbox ...
# 4      @AmazonHelp @115826 Yeah this is crazy we’re l...
# ...                                                  ...
# 18663   @ChipotleTweets Fort Worth off heritage Trace :(
# 18664  @ChipotleTweets Slow down! Half/half rice shou...
# 18665  @ChipotleTweets 818 Howe St, Vancouver, BC. 12...
# 18666  @ChipotleTweets I just got home from chipotle ...
# 18667  #lifeisburritoful after a full day of #BlackFr...
#
# [18668 rows x 2 columns]

# %%
for index in df.index:
    df.loc[index,'Company'] = '<SOS> ' + df.loc[index,'Company'] + ' <EOS>'
df
# Out:
#                                                  Company  \
# 0      <SOS> @115820 I'm sorry we've let you down! Wi...
# 1      <SOS> @115820 We'd like to take a further look...
# 2      <SOS> @115822 I am unable to affect your accou...
# 3      <SOS> @115826 I'm sorry for the wait. You'll r...
# 4      <SOS> @115827 Thanks for your patience. ^KM <EOS>
# ...                                                  ...
# 18663  <SOS> @157688 I'm reaching out to this locatio...
# 18664  <SOS> @157689 Sorry for the trouble. What loca...
# 18665  <SOS> @157689 I'm sharing your concerns with t...
# 18666  <SOS> @157690 I'd be disappointed too. Let a m...
# 18667  <SOS> @157692 Yay! I'll share some love with A...
#
#                                                     User
# 0      Way to drop the ball on customer service @1158...
# 1      @AmazonHelp 3 different people have given 3 di...
# 2      @115823 I want my amazon payments account CLOS...
# 3      @115828 How about you guys figure out my Xbox ...
# 4      @AmazonHelp @115826 Yeah this is crazy we’re l...
# ...                                                  ...
# 18663   @ChipotleTweets Fort Worth off heritage Trace :(
# 18664  @ChipotleTweets Slow down! Half/half rice shou...
# 18665  @ChipotleTweets 818 Howe St, Vancouver, BC. 12...
# 18666  @ChipotleTweets I just got home from chipotle ...
# 18667  #lifeisburritoful after a full day of #BlackFr...
#
# [18668 rows x 2 columns]

# %%
train_data, test_data = train_test_split(df, test_size=0.3, random_state=42)

# %%
text_data = np.concatenate((train_data['User'].values, train_data['Company'].values))
text_data
# Out:
# array(['@Uber_Support You\'ve literally taken $50 worth from me at least for being "late" .... late being 2 minutes after I come outside',
#        '@sainsburys Bracknell as always, the flagship shit hole of Berkshire. No one cares anymore and it wasn’t busy',
#        "@XboxSupport Ya know.. it's really hard to figure out how to find out how to order spare parts for the Xbox Elite Controller when this page never works.. URL_POSITION",
#        ...,
#        '<SOS> @133980 Hi Louise, you are right we do not own the car park but as we share it with other stores we can feed any issues back to those who do. Especially if these issues are putting our customers safety at risk! 1/3 <EOS>',
#        "<SOS> @116103 We'll make sure to get this straightened out. DM us, and we'll see you there. URL_POSITION <EOS>",
#        "<SOS> @135412 I'm really sorry about this Clare. Can you DM me your full name, address, email and order number please? I'll look into this. Guzala <EOS>"],
#       dtype=object)

# %%
MAX_NB_WORDS = 10000

tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(text_data)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 28790 unique tokens.

# %%
word_counts  = tokenizer.word_counts 
rare_words_number = 0 
for index, (key, value) in enumerate(word_counts.items()):
    if (value < 2):
        rare_words_number = rare_words_number + 1
        #print( index, key, value)
rare_words_number
# Out:
# 16318

# %%
train_data['User'].values[0]
# Out:
# '@Uber_Support You\'ve literally taken $50 worth from me at least for being "late" .... late being 2 minutes after I come outside'

# %%
seq = tokenizer.texts_to_sequences([train_data['User'].values[0]])
seq
# Out:
# [[145,
#   70,
#   521,
#   1096,
#   732,
#   863,
#   1119,
#   47,
#   33,
#   38,
#   842,
#   9,
#   238,
#   295,
#   295,
#   238,
#   54,
#   307,
#   170,
#   7,
#   340,
#   1460]]

# %%
tokenizer.sequences_to_texts(seq)
# Out:
# ["uber support you've literally taken 50 worth from me at least for being late late being 2 minutes after i come outside"]

# %%
train_X = tokenizer.texts_to_sequences(train_data['User'].values)
train_y = tokenizer.texts_to_sequences(train_data['Company'].values)

# %%
train_X[0]
# Out:
# [145,
#  70,
#  521,
#  1096,
#  732,
#  863,
#  1119,
#  47,
#  33,
#  38,
#  842,
#  9,
#  238,
#  295,
#  295,
#  238,
#  54,
#  307,
#  170,
#  7,
#  340,
#  1460]

# %%
MAX_ANSWER_LENGTH = 0
for el in train_data['Company']:
    MAX_ANSWER_LENGTH = MAX_ANSWER_LENGTH + len(el.split())
MAX_ANSWER_LENGTH = MAX_ANSWER_LENGTH / len(train_data['Company'])
print(MAX_ANSWER_LENGTH)
# Out:
# 22.605647815106757

# %%
MAX_QUESTION_LENGTH = 20
print(MAX_QUESTION_LENGTH)
MAX_ANSWER_LENGTH = 20
print(MAX_ANSWER_LENGTH)
# Out:
# 20
# 20

# %%
train_X = pad_sequences(train_X, maxlen=MAX_QUESTION_LENGTH, padding='post', truncating='post')
train_y = pad_sequences(train_y, maxlen=MAX_ANSWER_LENGTH, padding='post', truncating='post')

# %%
len(train_X[0])
# Out:
# 20

# %%
train_X[0][:18]
# Out:
# array([ 145,   70,  521, 1096,  732,  863, 1119,   47,   33,   38,  842,
#           9,  238,  295,  295,  238,   54,  307])

# %%
train_y_final_output = []
for i in train_y:
    train_y_final_output.append(i[1:]) 

train_y_final_output = pad_sequences(train_y_final_output, MAX_ANSWER_LENGTH, padding='post', truncating='post')

# %%
train_y_final_output[0][:50]
# Out:
# array([ 96,   1, 114, 102,   5,  12,   5,  24,  56,  22,   6,  28, 242,
#        156,  18,  10,  88,  78,   8,   0])

# %%
train_y[0][:18]
# Out:
# array([  3,  96,   1, 114, 102,   5,  12,   5,  24,  56,  22,   6,  28,
#        242, 156,  18,  10,  88])

# %%
from tensorflow.keras.utils import to_categorical
train_y_final_output = to_categorical(train_y_final_output, MAX_NB_WORDS)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Embedding, LSTM, Input


enc_inp = Input(shape=(20, ))
dec_inp = Input(shape=(20, ))

# %%
VOCAB_SIZE = MAX_NB_WORDS
embed = Embedding(VOCAB_SIZE+1, output_dim=20, 
                  input_length=20,
                  trainable=True                  
                  )

# %%
enc_embed = embed(enc_inp)
enc_lstm = LSTM(200, return_sequences=True, return_state=True)
enc_op, h, c = enc_lstm(enc_embed)
enc_states = [h, c]

# %%
embed2 = Embedding(VOCAB_SIZE+1, output_dim=20, 
                  input_length=20,
                  trainable=True                  
                  )

# %%
dec_embed = embed2(dec_inp)
dec_lstm = LSTM(200, return_sequences=True, return_state=True)
dec_op, _, _ = dec_lstm(dec_embed, initial_state=enc_states)

# %%
dense = Dense(VOCAB_SIZE, activation='softmax')
dense_op = dense(dec_op)
model = Model([enc_inp, dec_inp], dense_op)
model.compile(loss='categorical_crossentropy',metrics=['acc'],optimizer='adam')
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 20)]         0           []
#
#  input_2 (InputLayer)           [(None, 20)]         0           []
#
#  embedding (Embedding)          (None, 20, 20)       200020      ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, 20, 20)       200020      ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 20, 200),    176800      ['embedding[0][0]']
#                                  (None, 200),
#                                  (None, 200)]
#
#  lstm_1 (LSTM)                  [(None, 20, 200),    176800      ['embedding_1[0][0]',
#                                  (None, 200),                     'lstm[0][1]',
#                                  (None, 200)]                     'lstm[0][2]']
#
#  dense (Dense)                  (None, 20, 10000)    2010000     ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 2,763,640
# Trainable params: 2,763,640
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.fit([train_X, train_y],train_y_final_output,epochs=30, validation_split=0.2,
    callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
# Out:
# Epoch 1/30
# 327/327 [==============================] - 55s 154ms/step - loss: 5.5005 - acc: 0.1736 - val_loss: 4.9772 - val_acc: 0.1896
# Epoch 2/30
# 327/327 [==============================] - 50s 152ms/step - loss: 4.8152 - acc: 0.2115 - val_loss: 4.6965 - val_acc: 0.2348
# Epoch 3/30
# 327/327 [==============================] - 49s 151ms/step - loss: 4.5257 - acc: 0.2532 - val_loss: 4.4219 - val_acc: 0.2740
# Epoch 4/30
# 327/327 [==============================] - 45s 138ms/step - loss: 4.2248 - acc: 0.2952 - val_loss: 4.1636 - val_acc: 0.3131
# Epoch 5/30
# 327/327 [==============================] - 46s 141ms/step - loss: 3.9873 - acc: 0.3254 - val_loss: 3.9919 - val_acc: 0.3341
# Epoch 6/30
# 327/327 [==============================] - 43s 133ms/step - loss: 3.8174 - acc: 0.3455 - val_loss: 3.8773 - val_acc: 0.3465
# Epoch 7/30
# 327/327 [==============================] - 45s 139ms/step - loss: 3.6796 - acc: 0.3609 - val_loss: 3.7765 - val_acc: 0.3621
# Epoch 8/30
# 327/327 [==============================] - 45s 137ms/step - loss: 3.5611 - acc: 0.3734 - val_loss: 3.6958 - val_acc: 0.3721
# Epoch 9/30
# 327/327 [==============================] - 44s 136ms/step - loss: 3.4549 - acc: 0.3846 - val_loss: 3.6279 - val_acc: 0.3817
# Epoch 10/30
# 327/327 [==============================] - 45s 137ms/step - loss: 3.3584 - acc: 0.3947 - val_loss: 3.5737 - val_acc: 0.3893
# Epoch 11/30
# 327/327 [==============================] - 46s 141ms/step - loss: 3.2690 - acc: 0.4038 - val_loss: 3.5253 - val_acc: 0.3951
# Epoch 12/30
# 327/327 [==============================] - 46s 140ms/step - loss: 3.1858 - acc: 0.4129 - val_loss: 3.4852 - val_acc: 0.4008
# Epoch 13/30
# 327/327 [==============================] - 46s 142ms/step - loss: 3.1068 - acc: 0.4209 - val_loss: 3.4511 - val_acc: 0.4066
# Epoch 14/30
# 327/327 [==============================] - 46s 140ms/step - loss: 3.0330 - acc: 0.4285 - val_loss: 3.4260 - val_acc: 0.4099
# Epoch 15/30
# 327/327 [==============================] - 46s 141ms/step - loss: 2.9651 - acc: 0.4352 - val_loss: 3.4017 - val_acc: 0.4135
# Epoch 16/30
# 327/327 [==============================] - 45s 139ms/step - loss: 2.9010 - acc: 0.4416 - val_loss: 3.3843 - val_acc: 0.4182
# Epoch 17/30
# 327/327 [==============================] - 46s 142ms/step - loss: 2.8395 - acc: 0.4486 - val_loss: 3.3752 - val_acc: 0.4201
# Epoch 18/30
# 327/327 [==============================] - 45s 138ms/step - loss: 2.7800 - acc: 0.4548 - val_loss: 3.3582 - val_acc: 0.4257
# Epoch 19/30
# 327/327 [==============================] - 44s 135ms/step - loss: 2.7239 - acc: 0.4610 - val_loss: 3.3523 - val_acc: 0.4270
# Epoch 20/30
# 327/327 [==============================] - 46s 140ms/step - loss: 2.6684 - acc: 0.4680 - val_loss: 3.3497 - val_acc: 0.4299
# Epoch 21/30
# 327/327 [==============================] - 46s 141ms/step - loss: 2.6145 - acc: 0.4754 - val_loss: 3.3498 - val_acc: 0.4327
# Epoch 22/30
# 327/327 [==============================] - 46s 142ms/step - loss: 2.5613 - acc: 0.4831 - val_loss: 3.3387 - val_acc: 0.4374
# Epoch 23/30
# 327/327 [==============================] - 46s 140ms/step - loss: 2.5108 - acc: 0.4891 - val_loss: 3.3402 - val_acc: 0.4368
# Epoch 24/30
# 327/327 [==============================] - 42s 128ms/step - loss: 2.4616 - acc: 0.4954 - val_loss: 3.3394 - val_acc: 0.4387
# Epoch 25/30
# 327/327 [==============================] - 41s 126ms/step - loss: 2.4150 - acc: 0.5022 - val_loss: 3.3479 - val_acc: 0.4393

# %%
model.save_weights('weights/mixed_lstm.h5')

# %%
enc_model = Model(enc_inp, enc_states)

# %%
decoder_state_input_h = Input(shape=(200,))
decoder_state_input_c = Input(shape=(200,))

# %%
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# %%
decoder_outputs, state_h, state_c = dec_lstm(dec_embed , 
                                    initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
#decoder_outputs = dense(decoder_outputs)

# %%
dec_model = Model([dec_inp]+ decoder_states_inputs,
                                      [decoder_outputs]+ decoder_states)

# %%
test_question = tokenizer.texts_to_sequences([test_data['User'].values[2]])

#test_question = tokenizer.texts_to_sequences([train_data['User'].values[200]])
test_question
# Out:
# [[108, 3485, 241, 21, 53, 836, 1072, 1, 6750, 631, 603, 283]]

# %%
test_X = pad_sequences(test_question, maxlen=MAX_QUESTION_LENGTH, padding='post', truncating='post')
test_X
# Out:
# array([[ 108, 3485,  241,   21,   53,  836, 1072,    1, 6750,  631,  603,
#          283,    0,    0,    0,    0,    0,    0,    0,    0]])

# %%
test_answer = enc_model.predict( test_X )

# %%
empty_target_seq = np.zeros( ( 1 , 1) )
empty_target_seq
# Out:
# array([[0.]])

# %%
empty_target_seq[0, 0] = tokenizer.texts_to_sequences(['sos'])[0][0]
empty_target_seq
# Out:
# array([[3.]])

# %%
stop_condition = False
decoded_translation=''
i = 0
repeat = 0
while not stop_condition :
    dec_outputs , h, c= dec_model.predict([empty_target_seq] + test_answer )
    decoder_concat_input = dense(dec_outputs)
    sampled_word_index = np.argmax( decoder_concat_input[0, -1, :] )
    
    if i == 0:
        i = 1
        indes = np.argpartition(decoder_concat_input[0, -1, :], -10)[-10:]
        indes = tokenizer.sequences_to_texts([indes])
        print('\n', indes)
        print('\n', sampled_word_index)
    
    sampled_word = tokenizer.sequences_to_texts([[sampled_word_index]])[0] + ' '
    print(decoded_translation)
    if sampled_word != 'eos ':
        prev = decoded_translation
        decoded_translation += sampled_word
        if (prev.rstrip() == decoded_translation.rstrip()):
            repeat = repeat + 1
        else:
            repeat = 0

    if sampled_word == 'eos ' or len(decoded_translation.split()) > 18:
        stop_condition = True
    if repeat > 2:
        stop_condition = True

    empty_target_seq = np.zeros( ( 1 , 1 ) )  
    empty_target_seq[ 0 , 0 ] = sampled_word_index
    ## <SOS> - > hi
    ## hi --> <EOS>
    test_answer = [h, c]

print("Question: ", test_data['User'].values[2])
print("\nExpected: ", test_data['Company'].values[2])
print("\nGiven: ")
print(decoded_translation)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'"), but it was called on an input with incompatible shape (None, 1).
#
#  ["if this we're we oh hey sorry please hello hi"]
#
#  37
#
# hi
# hi there
# hi there please
# hi there please check
# hi there please check your
# hi there please check your dm's
# hi there please check your dm's for
# hi there please check your dm's for more
# hi there please check your dm's for more instructions
# Question:  @Delta ^^ possibly because it was asking him to swipe his credit card? ^*
#
# Expected:  <SOS> @136422 Thank you, Josh, and it's our pleasure to convey your family member to his destination and to give help if any need should arise. Standing by for you, if anything, good man. *ADB <EOS>
#
# Given:
# hi there please check your dm's for more instructions

# %%
def predict_answer(question, expected_answer):
    tokenized_question = tokenizer.texts_to_sequences([question])
    input_question = pad_sequences(tokenized_question, maxlen=MAX_QUESTION_LENGTH, padding='post', truncating='post')
    test_answer = enc_model.predict( input_question )
    empty_target_seq = np.zeros( ( 1 , 1) )
    empty_target_seq[0, 0] = tokenizer.texts_to_sequences(['sos'])[0][0]
    stop_condition = False
    decoded_translation=''
    i = 0
    repeat = 0
    while not stop_condition :
        dec_outputs , h, c= dec_model.predict([empty_target_seq] + test_answer )
        decoder_concat_input = dense(dec_outputs)
        sampled_word_index = np.argmax( decoder_concat_input[0, -1, :] )

        sampled_word = tokenizer.sequences_to_texts([[sampled_word_index]])[0] + ' '
        if sampled_word != 'eos ':
            prev = decoded_translation
            decoded_translation += sampled_word
            if (prev.rstrip() == decoded_translation.rstrip()):
                repeat = repeat + 1
            else:
                repeat = 0

        if sampled_word == 'eos ' or len(decoded_translation.split()) > 18:
            stop_condition = True
        if repeat > 2:
            stop_condition = True

        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        test_answer = [h, c]

    print("Question: ", question)
    print("\nExpected: ", expected_answer)
    print("\nGiven: ")
    print(decoded_translation)

# %%
for index, row in test_data[:200].iterrows():
    predict_answer(row['User'], row['Company'])
# Out:
# Question:  @SouthwestAir Any chances of flying nonstop to/from Las Vegas/Memphis?  We've been traveling this route for a few years with layovers in either Dallas and/or Chicago and majority of the plane walks to the next gate together.  THANKS!!
#
# Expected:  <SOS> @126117 Hi there. While we don’t have plans for direct flights between Las Vegas and Memphis in the immediate future. Please know that we are constantly reevaluating our flight schedules, and I have forwarded your feedback on to our Network Planning Team. ^LC <EOS>
#
# Given:
# hi i'm sorry to hear this please dm your confirmation number so we can take a look at this
# Question:  @AskPlayStation Yeah I've tried everything. Nothing.
#
# Expected:  <SOS> @118883 Please open the link sent previously and search for a deactivation form, please fill it to request the deactivation. <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @Delta ^^ possibly because it was asking him to swipe his credit card? ^*
#
# Expected:  <SOS> @136422 Thank you, Josh, and it's our pleasure to convey your family member to his destination and to give help if any need should arise. Standing by for you, if anything, good man. *ADB <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @Tesco cannot believe you take 24 hours or more to reply on your system to a customer ..we ara busy but once a fault is on the system response should be in 15 minutes ..not the automated no response email you get ..what is dm?..
#
# Expected:  <SOS> @133974 Hi Wendy, I've responded to your Direct Message. If there is anything else I can assist you with, please don't hesitate to contact us again. Thanks - John <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @XboxSupport What's up with that code though? All issues aside. Why no reference?
#
# Expected:  <SOS> @125840 Try restarting your console with these steps URL_POSITION to resolve that error code
#  ^RM <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @116136 “On Demand” is ridiculous w/ commercials. I can rewind what I just watched but, fast forward is still diabled cause were forced to watch the commercials again. Nobody has time for it. Ughh
#
# Expected:  <SOS> @139056 Hey, there. On Demand content is provided by the network. Availability, pricing, and features are subject to their discretion.​ -SG <EOS>
#
# Given:
# hi there we'd like to help with your internet service please dm your account number and phone number so
# Question:  @ChipotleTweets thanks for $3 bowl today! You are appreciated!!!
#
# Expected:  <SOS> @117726 We appreciate you, too! -Becky <EOS>
#
# Given:
# we don't have any info on this and we're here for you let us know if you need anything
# Question:  @115940 y’all got anymore of them Sailor Moon Crystal episodes  __EMOJI__pensive_face URL_POSITION
#
# Expected:  <SOS> @124055 Hi! No news on more eps at the moment, but we'd be happy to share your interest in seeing more available with our team! <EOS>
#
# Given:
# hi there we'd like to help with your service please send us a dm with your email address so
# Question:  Thanks so much @116136 for allowing me to see the parade this morning and nothing else. #alwayssomethingwithyouguys #ialwayshavetoresetmybox
#
# Expected:  <SOS> @140146 Hi! I'd be happy to help you with your services. What's going on? -EM <EOS>
#
# Given:
# sorry to hear that please check your dm's for more instructions
# Question:  @115955 @Ask_Spectrum no rebuttal? Yea, I think this would be pretty hard to justify from your end. The customer first attitude is really apparent.
#
# Expected:  <SOS> @151474 Good morning Ryan, is there something I can help you with?  Please Follow/DM us your account information including the full address and phone number so that I may assist you. ^JF <EOS>
#
# Given:
# our apologies for the delay this is due to a fault with the signalling system is there anything i
# Question:  @AskPlayStation I don’t have anything in my DMs.
#
# Expected:  <SOS> @120289 Please check your DMs again. <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @virgintrains do you have revised arrival time at rugby for the delayed 735 chester to Euston
#
# Expected:  <SOS> @130836 This service looks to be running 19 late. We don't have an expected arrival time at the moment, Andy ^LC <EOS>
#
# Given:
# hi apologies for the delay this morning did you buy this from our website are you travelling on please
# Question:  @ChipotleTweets is your mobile ordering system down?
#
# Expected:  <SOS> @118772 It's just turned off for tonight during our Boorito promo. It'll be back on tomorrow. My apologies for any frustration. -Becky <EOS>
#
# Given:
# we don't have any info on this and we're here for you and we'll be sure to share your
# Question:  @sainsburys it's not the easiest store to be able to try clothes on!!!! URL_POSITION
#
# Expected:  <SOS> @136768 Sorry Karen, were you unable to try on some clothes? Which store is this in? Ewan <EOS>
#
# Given:
# hi there i'm sorry to hear this please dm your confirmation number so we can take a look at
# Question:  @Delta awesome gate agents working at CID and MSP today. Super helpful in getting us where we needed on Turkey Day.
#
# Expected:  <SOS> @141315 Awesome Lesley. Thank you for letting us be your ride today! Have a wonderful holiday!  __EMOJI__smiling_face_with_smiling_eyes *TKR <EOS>
#
# Given:
# we're sorry to hear that please dm your confirmation number so we can take a closer look kellenf
# Question:  @AskPlayStation i forgot my date of birth of my account
#
# Expected:  <SOS> @151856 Sorry for the delay! Do you need to change the password? <EOS>
#
# Given:
# please follow us via twitter and let us know so we can assist
# Question:  @Tesco Done, not sure what a sc code is.
#
# Expected:  <SOS> @136382 Hey Sophie, I've replied to your DM! :) - Jazzie <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @AskPlayStation Our PS4 is not working. It powers on and off and we can hear the disc moving. The disc ejects and inserts fine, but it just doesn't show up on any of the tvs. Not sure what to do. We have changed HDMI cables and that did not help.
#
# Expected:  <SOS> @151852 Hey Kimie. Have you tried using a different TV? <EOS>
#
# Given:
# sorry to hear that please send us a dm with your email address so we can connect
# Question:  @VirginTrains just wanted to make you aware that your staff on the 16.20 from London to Manchester have been excellent
#
# Expected:  <SOS> @125745 Thanks for your comments, Stuart. We'll pass this onto the team ^MM <EOS>
#
# Given:
# i'm sorry to hear this was your experience with us please dm us your confirmation number so we can
# Question:  Dear @ChipotleTweets ,
#      Please invest in opening a store here in Hawaii.... I’m going through withdrawals!
#
# Expected:  <SOS> @130216 I hope we can one day! -Jen <EOS>
#
# Given:
# we're sorry to hear that please send us a note at url position so our team can connect
# Question:  @SouthwestAir Thank you! Booked
#
# Expected:  <SOS> @122825 Can't wait to see you onboard. Happy travels! ^SJ <EOS>
#
# Given:
# we don't have any info on this and we're here for you and we'll be sure to share your
# Question:  @ComcastCares
# #mobile_Care
# How long it takes when I add new channels to my account to be active on my TV?
#
# Expected:  <SOS> @136942 When you ad channels they will typically be available right away. If you need help changing your service send a DM anytime. -JB <EOS>
#
# Given:
# i apologize for the inconvenience i will be happy to help can you please dm your full name and
# Question:  Spotify needs to have an option to go straight to singles.
#
# Expected:  <SOS> @125449 Hey Callum! We're always open for feedback. Can you give us a bit more info about your idea? We'll be waiting /MC <EOS>
#
# Given:
# hey there can you please dm us your account's email address we'll take a look backstage nq url position
# Question:  . @ChipotleTweets when your employees talk shit right in front of me in Spanish and think I don't understand it? #entiendo
#
# Expected:  <SOS> @116992 That's troubling to hear. Please provide more details: URL_POSITION -Becky <EOS>
#
# Given:
# we can help with your internet service concern please dm your account number and phone number so i can
# Question:  @125650 @comcastcares That’s the beauty of having a monopoly. They don’t even have to *try* to provide good service or fix problems.
#
# Expected:  <SOS> @125649 Hi, Stephanie! Thanks for reaching out. Let’s get that Internet issue fixed. Please DM your full name, address, and phone number? -GO <EOS>
#
# Given:
# hello i would like to look into this for you please send us a dm with your email address
# Question:  @AmericanAir talk about ripping off the public, your airfare prices are insanely ridiculous. In one day the price went up $110.  #Ripoff
#
# Expected:  <SOS> @136915 It sounds like our seats are going fast, Kristel. All our fares are based on advanced purchase and seat availability. <EOS>
#
# Given:
# we're sorry to hear this was your experience with us we hope you have a great flight
# Question:  @British_Airways Hence the word ‘goodwill’. Executive club for nothing less than 10 years doesn’t get you goodwill with your airline then that’s just sad. No class whatsoever was displayed today.
#
# Expected:  <SOS> @140254 I'm sorry you're disappointed, Amadihoha. I'm afraid we have to remain fair and consistent with Executive Club perks. ^Kimbers <EOS>
#
# Given:
# hi there sorry for the delay this morning due to congestion on the train you are working to resolve
# Question:  @116316 Hi. How can I restrict results to German language books, while searching titles on amazon.de?
#
# Expected:  <SOS> @116315 Hi, just a question at the beginning - do you prefer answers in German or English? ^NW <EOS>
#
# Given:
# hi there sorry to hear that please send us a dm with your email address so we can follow
# Question:  Dear @115955 , you are literally the fucking worst. I hate that you are the only provider in my area. I’m willing to move just to get away from you. Fuck you. Do better.
#
# Expected:  <SOS> @140721 Our apologies for any frustrations or inconvenience Ariel. Is there anything we may be able to assist with? ^AP . <EOS>
#
# Given:
# hello i am sorry to hear about the service issues please dm us your account's email address we'll take
# Question:  @sainsburys Which link?
#
# Expected:  <SOS> @127054 Sorry Fiona. The link will be below now. Lauren URL_POSITION <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @British_Airways Thanks to you for your beautiful answer.
#
# Expected:  <SOS> @139450 Tolkien was the love of my life and never knew it, Mr Bombadil! ^Kimbers <EOS>
#
# Given:
# hi there can you confirm the store you bought this from steven
# Question:  @Delta  Hi, I just checked in for my flight tomorrow. It says I’m confirmed but on the standby list. What does that mean? Thanks.
#
# Expected:  <SOS> @125203 Hi Jennifer! Please allow me just few a minutes to review your reservation details and I will be right back with you.  *HAN <EOS>
#
# Given:
# thanks for reaching out to us can you dm us your account's email address we'll take a look backstage
# Question:  @Delta BOI ticket agent a lot to be desired. Zero customers, attitude, no priority tags, put out to do seat assignments? True anomaly of Delta worldwide ‘17.
#
# Expected:  <SOS> @142011 Hi. I expect all employees to be helpful &amp; professional at all times. My apologies for the issues. Allow me a few minutes to review your reservation. *HJH <EOS>
#
# Given:
# thanks for the shout out we'll pass this logged with our team so we can help with this for
# Question:  @hulu_support Why is one single episode of Ray Donovan expiring December 5th? Its the 6th episode in the 5th season, so why?
#
# Expected:  <SOS> @141933 We're looking into the Ray Donovan expiration. For your WL, which device do you use? For now, please try a quick device reboot <EOS>
#
# Given:
# hi there sorry for the delay this morning due to a fault with the signalling system is there for
# Question:  @hulu_support So if I take off the live TV option, it'll work how I want?
#
# Expected:  <SOS> @130556 You only need to check-in if you are subscribed to Live TV. Here's how to manage your add-ons: URL_POSITION. <EOS>
#
# Given:
# hi there we can help you with the service you can find helpful troubleshooting tips here url position
# Question:  @hulu_support Apple TV Gen 4. It’s happened ever since the 5.8 or 5.8.1 update. The app works fine (as fine as usual) except account validation at open.
#
# Expected:  <SOS> @127665 Yikes! Try running though: URL_POSITION --including uninstalling/reinstalling our app. Any improvement after? <EOS>
#
# Given:
# we're sorry to hear this was your experience with us we hope you have a great flight jt
# Question:  @GWRHelp Thanks. Just seems archaic I need to hand write a paper form and send by post in 2017.
#
# Expected:  <SOS> @148209 The process is being looked at and we hope to be able to streamline it soon. However at present I'm afraid the form needs to be printed and posted. Lewis <EOS>
#
# Given:
# hi there can you confirm the store you bought this from steven
# Question:  @115714
# New customers get $25 per line unlimited, right?
# What does a loyal cust. for 20+ get? Especially when the service has been crap?
#
# Expected:  <SOS> @118790 Hi there, we hope to have all our customers feeling appreciated. It is disappointing to received contrary feedback. -AJS <EOS>
#
# Given:
# hi there we'd like to help with your internet service please dm your account number and phone number so
# Question:  Amma asking @2084: Can you fix my @115858 thumbprint for me? I think my thumb has changed from washing dishes.
#
# Expected:  <SOS> @123190 We can help with your Touch ID. Try these steps to start: URL_POSITION Did that help? <EOS>
#
# Given:
# hey there we can help with this please send us a dm with your email address so we can
# Question:  @116240 Hi there! If an account is not following the Code of Conduct here: URL_POSITION 1/2 ^JA
#
# Expected:  <SOS> @116240 then we'd recommend reporting them directly via the console so that the Enforcement team is aware. 2/2 ^JA <EOS>
#
# Given:
# hi there we can help you with the service issues please dm your account number and full address cs
# Question:  @116130 I’m being charged for premium but my account is saying I’m not premium and won’t give me premium features?
#
# Expected:  <SOS> @123093 Hey Liz! Could you send us a DM with your account's email address? We'll take a look backstage /MA URL_POSITION <EOS>
#
# Given:
# 115913 hey there we can help you with the service issues please dm your account number and phone number
# Question:  @SpotifyCares never mind! you're good
#
# Expected:  <SOS> @133956 Thanks for the kind words. If we can help with anything else, you know where to find us  __EMOJI__slightly_smiling_face /AY <EOS>
#
# Given:
# hey there can you dm us your account's email address or username we'll take a look backstage nq url
# Question:  @XboxSupport on the flip side this is missing from the one X menu so heads up. 4k assets only and only when they want to download so check before play
#
# Expected:  <SOS> @143149 Looks like you may be reaching out to another user but since you tagged us we want to make sure you don't have any questions.  ^IS <EOS>
#
# Given:
# hi there can you please dm us your account's email address we'll take a look backstage lm url position
# Question:  @TMobileHelp Worst Network Ever..does not even compare to Verizon
#
# Expected:  <SOS> @148135 We certainly don't want you feeling this way, Brian! Send us over a DM so we can take a further look into things! URL_POSITION *MikePerez <EOS>
#
# Given:
# hey there we can help you with please feel free to dm us your account number and phone number
# Question:  @AmazonHelp Deluxe edition on September 16th. It definitely had the pre orders on the profile because that’s why I ordered. Also why I paid for Prime..
#
# Expected:  <SOS> @116088 Could you link us to the page of the item on our website? This will allow us to take a closer look at all options. ^VB <EOS>
#
# Given:
# sorry for the delay to our team can you please dm your full name address and email address so
# Question:  @GWRHelp So the 0814 Slough to Reading service is not only late AGAIN but running a carriage down. Explanation?
#
# Expected:  <SOS> @146369 Hello. I am sorry for the disruption this morning, we're looking into the delay. - Jordan <EOS>
#
# Given:
# hi there sorry for the delay this morning due to a fault with the signalling system and we'll be
# Question:  @comcastcares What’s D S?
#
# Expected:  <SOS> @117234 I'm not sure what you mean, but I'll be happy to look into it. Would you please DM the full service address and phone number? -JN <EOS>
#
# Given:
# hey there we can help you with the service you can find helpful troubleshooting tips here url position
# Question:  @115900 If you just want to tell me if there's internet outages in Salisbury Mass that'd be great.
#
# Expected:  <SOS> @116676 Hi, I would love to help. Please DM me the phone # associated with the account &amp; the service address. -Jules <EOS>
#
# Given:
# i apologize for the inconvenience i will be happy to help can you dm us your full name address
# Question:  @AskPlayStation Hi! Having issue with an old account, no idea what the login/email is for it but I know the ID
#
# Expected:  <SOS> @116217 Hi there, Please check your DM's for further instructions. <EOS>
#
# Given:
# we're sorry to hear that please send us a dm with your email address so we can connect
# Question:  @SouthwestAir Hi! How do I go about initiating a refund for a prepaid extra seat on a RT booking I just completed? Thank you!
#
# Expected:  <SOS> @123564 We'd be happy to take care of you here! Can you DM your confirmation number? ^JT URL_POSITION <EOS>
#
# Given:
# sorry to hear that please check your dm's for more instructions
# Question:  Thankful for a lot of stuff, especially @ChipotleTweets  #HappyThanksgiving
#
# Expected:  <SOS> @144051 Happy Thanksgiving to you too. -Tara <EOS>
#
# Given:
# we don't have any info on this and we're here for you and we'll be sure to share your
# Question:  @comcastcares You keep telling me what I have to do.  I got it the first time.  Get this, I am to be treated with common courtesy and respect and we can continue this conversation when someone with authority contacts me to negotiate a refund.
#
# Expected:  <SOS> @134935 We truly appreciate you reaching out to us to get this issue resolved. However we are not able to initiate a DMs. In order for us to prove the level of assistance you have requested we must have you send us a DM. Please allow us an opportunity to assist you via DM. -Claude <EOS>
#
# Given:
# hello i am sorry to hear about the service issues please dm us your account's email address we'll take
# Question:  @115858 @AppleSupport @1456 his new ios 11.0  I have to restart my phone at least four times a day because it is blocked by everything
#
# Expected:  <SOS> @123501 We want to help get your iPhone working properly. Which exact iOS version and iPhone are you using? <EOS>
#
# Given:
# we'd like to help with your service send us a dm with your email address so we can assist
# Question:  Where’s your Black Friday sale? @SouthwestAir
#
# Expected:  <SOS> @151323 While we don't have a sale specific to Black Friday, for our best deals: URL_POSITION. Hope to share the skies soon! ^CT <EOS>
#
# Given:
# hi there sorry for the delay this morning due to a fault with the signalling system for this time
# Question:  @hulu_support Oh I’m very disappointed to be honest
#
# Expected:  <SOS> @133855 Trust that we hear you! We've saddened to not have the rights to the entire sequences as well. The request for access to all of episode 22, as well as the Mick Jagger portion has been requested as promised. Fingers crossed!  __EMOJI__green_heart <EOS>
#
# Given:
# sorry to hear that please check your dm's for more instructions
# Question:  .@SouthwestAir I didn’t get my points from my last flights, who should I contact about that?
#
# Expected:  <SOS> @116708 Oh no! You can add your flights here, Rachel: URL_POSITION ^SL <EOS>
#
# Given:
# i apologize for the inconvenience i will be happy to help please dm your confirmation number so we can
# Question:  @TMobileHelp Hey guys, no worries. It all works again now.
#
# Expected:  <SOS> @143425 Awesome! We are here for you #TwentyFourSeven.
# #HappyHolidays    __EMOJI__smiling_face_with_smiling_eyes *RehanaAnwar <EOS>
#
# Given:
# hey there we can help you with the service you can find helpful troubleshooting tips here url position
# Question:  @sainsburys I live a distance away. To avoid unnecessary journey can you confirm Age 3-4 will be held for me instore and I will go tomorrow morning first thing. Please advise ASAP thank you.
#
# Expected:  <SOS> @131772 Sorry for the delay, have you made the journey to our store? Maclaine <EOS>
#
# Given:
# hi there sorry for the delay this morning due to a fault with the signalling system is there we'll
# Question:  @AppleSupport I just followed some steps on the apple forum, and it worked. So I guess it’s solved, thank you.
#
# Expected:  <SOS> @125146 Glad to hear you were able to update. Let us know if we can be of any other assistance. <EOS>
#
# Given:
# i am sorry to hear about the service issues please dm us your account number and phone number so
# Question:  @115888 Hey, guys, some intern must have typed the name wrong or something... But the song’s title is actually “Fantastic BABY”, not BOY.
#
# Xoxo URL_POSITION
#
# Expected:  <SOS> @133315 Hey! The cavalry's here. Can you send us the Song Link? Just tap the three dots &gt; Share &gt; Copy Link. We'll look under the hood /PK <EOS>
#
# Given:
# hey there can you dm us your account's email address or username we'll take a look backstage nq url
# Question:  @115911 I checked my dunkin promo 4 times. It is correct. But not letting me register a new card. Please help
#
# Expected:  <SOS> @119242 We can definitely assist you with this, Shawn. Send us a DM so you can #GetThanked *RickK <EOS>
#
# Given:
# i apologize for the inconvenience i will be happy to help please dm your account number and phone number
# Question:  I love  __EMOJI__red_heart️ @SouthwestAir but there was a VERY rude employee boarding flight 728 out of Denver this morning. (I’m A list preferred)
#
# Expected:  <SOS> @127794 We hate to see you upset, Marci. Mind DMing us your confirmation number and more details? ^SJ <EOS>
#
# Given:
# we don't have any info on this and we're here to help with your service please dm us your
# Question:  @SpotifyCares see screenshot below - 'premium for family' page not working in internet explorer. Please can you fix so I can add a family member? Thanks URL_POSITION
#
# Expected:  <SOS> @134862 Hey Jade! Can you try giving it another go using a different web browser or an incognito/private window? Does that help? /RE <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  My internet is down yet again @Ask_Spectrum
#
# Expected:  <SOS> @120803 Sorry you're having issues with your internet. Please DM your account info and I'd be happy to take a look. ^LS <EOS>
#
# Given:
# i apologize for the troubles with your internet service can you please dm your account number and phone number
# Question:  @ChipotleTweets Slow down! Half/half rice should not mean 1/2 scoop of 1 rice &amp; 10 grains of the other. Also had to repeat each item &gt;2x today. Staff glared at me as if it's my English when the prev staff in line heard all items w/o issues. Repeat ok but what's w/ the attitude?
#
# Expected:  <SOS> @157689 Sorry for the trouble. What location was this? -James <EOS>
#
# Given:
# hi there i am sorry to hear that please dm your confirmation number so we can take a
# Question:  @116136 outage in Grandville mi? Internet speed is at 5 mb/second. Good thing I’m paying $50/month for that..oh wait #comcast
#
# Expected:  <SOS> @126461 Hello, thanks for reaching out about your service interruption concerns and I'm happy to help. Can you DM the full address? ~AT <EOS>
#
# Given:
# we are here to help please dm us your account's email address we'll take a look backstage nq url
# Question:  @hulu_support The feed keeps buffering on a regular basis. I love the concept of Hulu TV but this is getting terrible. PS Vue anyone?
#
# Expected:  <SOS> @130111 Let's fix that! What device are you experiencing this on? Are you running into buffering during live TV or on-demand content? <EOS>
#
# Given:
# hi there can you dm us your account's email address or username we'll take a look backstage nq url
# Question:  @118506 @AmazonHelp Amazon has lost its credibility by buying cheap products from other portals like ebay and selling over their platform. Really cheap
#
# Expected:  <SOS> @118505 you with an update at the earliest. (2/2)^AU <EOS>
#
# Given:
# i'm sorry to hear this was your experience with us please dm us your confirmation number so we can
# Question:  @sainsburys could you kindly let me know if the SmartShop app is out of action please?
#
# Expected:  <SOS> @116809 Hi Andrew, we're not aware of any ongoing issues. Can you provide some more info about the issues you're having? Corey <EOS>
#
# Given:
# hi there can you confirm the store you usually shop on please rach
# Question:  @Ask_Spectrum But you still haven’t answered my question: what happens if I am not here for my install appt?
#
# Expected:  <SOS> @133178 Good Morning, Allen. How can we be of assistance today? ^AH <EOS>
#
# Given:
# good morning i'm sorry to hear this please dm your confirmation number so we can look into this for
# Question:  @115913 Hope you &amp; your Family had a wonderful Holiday . BTW  __EMOJI__heavy_heart_exclamation️
#  I LOVE T-Mobil . BUT I went to pay my bill an I asked about a wire I bought that didn't work , The store Rep was EXTREMELY RUDE told me just buy another wire . I don't have a newer phone (it's 3 yrs old ) or a lot of $$.
#
# Expected:  <SOS> @143419 @115913 We always want to take great care of you, Tracy and make sure we're exploring all options. Please send a DM our way. URL_POSITION *MikeRice <EOS>
#
# Given:
# 115913 we want to help with your service issues please dm us your account number and phone number so
# Question:  @ChipotleTweets went to chipotle to get $3 bowls and got charged regular price even though my sis was wearing a costume right next to me ??
#
# Expected:  <SOS> @118766 Were you in a costume, as well? -Becky <EOS>
#
# Given:
# we're sorry to hear that please send us a note at url position so our team can connect
# Question:  @115911 T-force be stressing me out this Thanksgiving. They lost my phone and just copy/paste long text about why they’re too busy to help. They need a systems upgrade @115913 please
#
# Expected:  <SOS> @140116 @115913 We want to take care of you and get you back to enjoying your Thanksgiving, Andrew. Please reply back to our DM thread so we can continue helping: URL_POSITION *DanKing <EOS>
#
# Given:
# hey there we can help with this please send us a dm with your email address so we can
# Question:  Just tried @ChipotleTweets queso....not impressed. It was runny and somewhat tasteless. 4/10 URL_POSITION
#
# Expected:  <SOS> @128168 Sorry you're not a fan. We'll continue to work out the kinks while using whole, unprocessed ingredients. -AC <EOS>
#
# Given:
# we don't have any info on this and we're here to help with your internet services can you please
# Question:  @Tesco I stayed up to midnight and was on your website from 11:50pm waiting for the slot date to change to offer Sat 23rd. When it did not one slot was available....not one! Thanks for nothing Tesco....off to Sainsburys i go!
#
# Expected:  <SOS> @120477 Hey Rob! I'm really sorry about this. Have you checked again this morning at all? Can you also DM me your name, home address and postcode and I will feed this back for you? TY - Eilish <EOS>
#
# Given:
# hi there can you dm us your account's email address or username we'll take a look backstage nq url
# Question:  Experimental #GMO crops are at Sainsbury Lab which isn't actually connected to @sainsburys who do, nonetheless sell meat eggs and dairy from #GMfed animals without letting their customers know #FeedmetheTruth  URL_POSITION
#
# Expected:  <SOS> @132946 Hi there, I can confirm that none of our own brand products are genetically modified. Steven <EOS>
#
# Given:
# hi there sorry for the delay this morning due to a fault with the signalling system is there we'll
# Question:  @sainsburys please please please don't use foil backed labels on your pumpkins next year 30 mins scraping off the foil &amp; glue not fun  __EMOJI__thumbs_up __EMOJI__light_skin_tone
#
# Expected:  <SOS> @124761 Sorry about that! Which store do you purchase these from, John? Chris. <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @AppleSupport  hey what’s going on with the letter I . When i start to. Type this happens below URL_POSITION
#
# Expected:  <SOS> @117504 Let's look at this together. To begin, are you completely updated to iOS 11.1? <EOS>
#
# Given:
# we'd like to help with your internet service can you please dm your account number and phone number so
# Question:  @sprintcare @129471 Service is garbage in South Florida. Literally use WiFi everywhere.
#
# Expected:  <SOS> @129472 Please follow us on twitter, so that we can continue to assist you. -JC <EOS>
#
# Given:
# hey there we can help you with the service issues please dm your account number and phone number so
# Question:  @VirginTrains @126035 @136497 So the same as the East Coast and on the West Coast. Looks nice.
# The old livery seen this morning passing Smethwick Galton Bridge. URL_POSITION
#
# Expected:  <SOS> @136496 @126035 @136497 You're seeing them all today. ^PA <EOS>
#
# Given:
# hi there can you confirm the store you received please provide your confirmation number and we'll take a look
# Question:  @hulu_support Ok thanks! I have resolved to shut off Autoplay..we really should have an option to autoplay a lineup of our shows on our Watchlist
#
# Expected:  <SOS> @119274 We're glad to hear that helped and we'll be sure to share the interest in having this kind of feature with our dev team! <EOS>
#
# Given:
# we're sorry to hear this was your experience with us we will be happy to help with any inconvenience
# Question:  Great flight and on the ground in Verona ahead of schedule, thanks @British_Airways  __EMOJI__raising_hands URL_POSITION
#
# Expected:  <SOS> @130957 Thanks for your Tweet, Richard. I'm pleased to hear you enjoyed your flight and you arrived early too. ^Kev <EOS>
#
# Given:
# we're sorry to hear this was your experience with us we hope you have a great flight
# Question:  @123843 @AppleSupport yea same here idk what's wrong
#
# Expected:  <SOS> @124686 Here is a great article to help you with that update: URL_POSITION <EOS>
#
# Given:
# hello i would like to look into this for you please send us a dm with your email address
# Question:  @115858 this glitch is blowing mine. please fix it.
#
# Expected:  <SOS> @118357 We're here to help with any issues you may be having. Tell us what's going on to get started. <EOS>
#
# Given:
# we'd like to help with your internet service concern please dm your account number and phone number so we
# Question:  @SouthwestAir failure again on baggage. Service failed in handling situation as well. Disappointed and thinking about a change.
#
# Expected:  <SOS> @119497 We're saddened to learn you're upset with us. Is there anything we can assist you with here? ^MA <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @AmazonHelp Now which information left to give u???kindly read previous msg.
#
# Expected:  <SOS> @120227 here: URL_POSITION. Kindly check and reply to our email for assistance. (2/2) ^MO <EOS>
#
# Given:
# thanks for the shout out we'll pass this logged with our team so we can help with this for
# Question:  @hulu_support Yes and it has the newest available web.os version as well.
#
# Expected:  <SOS> @128778 Got it! In regard to the playback failure, please contact us here: URL_POSITION. We'll go over next steps from there! <EOS>
#
# Given:
# sorry to hear that please check your dm's for more instructions
# Question:  The @AmericanAir Flagship Lounge is 🤩 __EMOJI__smiling_face_with_heart-eyes __EMOJI__smiling_face_with_sunglasses.  Look at these goodies! URL_POSITION
#
# Expected:  <SOS> @122130 We love our comfort food! Looks so #yummy. <EOS>
#
# Given:
# we know how important to be professional and courteous are you to have a great flight jt
# Question:  @sainsburys Hi Robbie, no need for Nectar points, we just want to get something reasonable to eat before we do our shopping. I know it’s not going to be exceptional, but at least be reasonable and match ‘as advertised’ each time. The customer service also needs to be improved there. Simon
#
# Expected:  <SOS> @117487 Could you DM us some more information on the service issue with the link below? We'll make sure this is fed back. Maclaine URL_POSITION <EOS>
#
# Given:
# hey there can you dm us your account's email address or username we'll take a look backstage nq url
# Question:  @AmericanAir AA2266, I already have a solution... he's here all of a sudden but it's just pretty messed up.
#
# Expected:  <SOS> @123730 We hear your frustration and will have you on your way soon. Our sincere apologies for any inconvenience caused. <EOS>
#
# Given:
# we're sorry to hear that please send us a note at url position so our team can connect
# Question:  @1756 @115858 Mine is shite mate....crashing, turning itself off, apps randomly freezing, won’t let me call anyone @115858 @AppleSupport
#
# Expected:  <SOS> @124304 We'd like to look into this with you. When did these issues begin? Tell us in a DM. URL_POSITION <EOS>
#
# Given:
# we want to help please dm us your account's email address we'll take a look backstage nq url position
# Question:  i just spent $3.00 even on a boorito from @ChipotleTweets  __EMOJI__smiling_face_with_heart-eyes
#
# Expected:  <SOS> @115972 Best day of the year! -Becky <EOS>
#
# Given:
# hi there we can help you with the service issues please dm your account number and phone number so
# Question:  Always a great day when Lynne's your train manager #bigfan @VirginTrains
#
# Expected:  <SOS> @134456 Which service was this on, Dan? ^LC <EOS>
#
# Given:
# we're sorry to hear this is your experience with us we can help with anything else
# Question:  @AmericanAir Correct, after multiple phone calls, they protected us in Econ later. However, that doesn’t do anything to make this right. My girlfriend and  I missed Thanksgiving dinner with family 100% due to AA’s maintenance issues resulting in 6+ hours of delay.
#
# Expected:  <SOS> @143990 Please meet us in DM, John. We'd like to review your reservation. <EOS>
#
# Given:
# we appreciate your feedback jd out the day becky
# Question:  @Tesco no lunch today for me. Got sold an out of date sandwich!  __EMOJI__nauseated_face#disgusting URL_POSITION
#
# Expected:  <SOS> @126812 Hi Jessica, I'm sorry you were sold an out of date sandwich. I can understand your disappointment. 1/3 <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  I'm at BA Galleries Club Lounge South - @british_airways in Hounslow, London URL_POSITION
#
# Expected:  <SOS> @128166 It's good too see you again, Charles! How was the flight? ^SR <EOS>
#
# Given:
# i can look into this for you please dm us your account's email address we'll take a look backstage
# Question:  Amazing service @Delta haven't had such a good flying experience ina a while. Uio-jfk last week and ewr-atl today were perfect in flight and at airport experience.
#
# Expected:  <SOS> @138984 HI Juan. Thank you so much for the wonderful compliment, and we are so happy you enjoyed our service.  __EMOJI__smiling_face_with_open_mouth_&_smiling_eyes *TMS <EOS>
#
# Given:
# our apologies for the delay this is due to a fault with the signalling system and will be in
# Question:  @AmericanAir Do you have a plan to notify passengers well in advance of pilot related cancellations or just wait til the day before?  Will you protect passengers on other airlines if flights are cancelled b/c of pilot shortages?
#
# Expected:  <SOS> @134911 We're planning to fly as scheduled, Shaun. <EOS>
#
# Given:
# hi sorry for the delay this morning our team will be able to assist you onboard soon
# Question:  I don’t know if it’s either my #iPhone 6 or The new #iOS update I installed yesterday but, my battery had been draining out! #Apple @115858
#
# Expected:  <SOS> @123667 You're in the right place. Let's meet up via DM so we can dig in to this in greater detail. URL_POSITION <EOS>
#
# Given:
# i apologize for the inconvenience i will be happy to help please dm your confirmation number so we can
# Question:  @GWRHelp The 7:41 from wokingham to Guildford
#
# Expected:  <SOS> @120652 The service is currently running 4 minutes late. Apologies for any inconvenience - Josh <EOS>
#
# Given:
# hi there i'm sorry to hear this can you please dm your confirmation number and we'll take a look
# Question:  @115911 @TMobileHelp sent a IM.
#
# Expected:  <SOS> @130309 Perfect, thanks for the DM, meet you there! *ErikaHoleman <EOS>
#
# Given:
# hey there we can help with this send us a dm and we'll continue to url position
# Question:  @sainsburys just got a credit card off you guys, is there a mobile app I can use to track everything? Or is it just online banking?
#
# Expected:  <SOS> @123423 Thanks for getting in touch, Alex. We don’t have an app right now but it’s something we’re looking in to. Marc <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @SouthwestAir Also, yes, this holiday season!!!
#
# Expected:  <SOS> @154837 Awesome! We're glad we can be there for your family! ^SF <EOS>
#
# Given:
# thanks for the shout out and we're glad to hear that we can help with this please dm us
# Question:  What channel is the SEC N rework on Spectrum?
#
# Expected:  <SOS> @142253 I can look up the channel number if you could provide your zip code, or you can access our channel lineup at URL_POSITION <EOS>
#
# Given:
# i can help with your internet service can you please dm your account number and phone number so we
# Question:  @Tesco Hi! I ordered something online and need to return it but don't have the receipt. Can I use a print out of the order? Thanks!
#
# Expected:  <SOS> @133971 Hi Anahita, I do apologise about this, can you please get back to us with your full name, address and also order number? We'll look into this for you. TY - Sheryll <EOS>
#
# Given:
# hi there can you dm us your account's email address or username we'll take a look backstage nq url
# Question:  @AppleSupport my phone was acting up. I then restarted it and now all it does is stay on the apple logo when I turn it on. Wtf
#
# Expected:  <SOS> @119216 We’ve got your back. Let us know if the steps in this article help with your iPhone: URL_POSITION <EOS>
#
# Given:
# we'd like to help with your internet service can you please send us a dm with your email address
# Question:  Did not see that coming sainsburys #sainsburys URL_POSITION
#
# Expected:  <SOS> @122646 We're very excited Christian. Steven <EOS>
#
# Given:
# we don't have any info on this and we're here to help with your service please dm us your
# Question:  @Uber_Support do you have services for differently abled in Mumbai
#
# Expected:  <SOS> @120706 Here to help! For more info about UberAssist, visit this link; URL_POSITION. <EOS>
#
# Given:
# here to help send us a note at url position so our team can connect
# Question:  Lets see if anybody cares?  @115911 u live up to your word?  I will erase every MSG &amp; promote.  So far no loyalty &amp; going on about 20 hrs of tweets w-no results #INSANE URL_POSITION
#
# Expected:  <SOS> @130878 Hey there! We would love to assist you and would need to communicate through DM to access your account. We take your concerns very seriously and hope to work towards a resolution with you! *BrookeK <EOS>
#
# Given:
# i would like to look into this for you please send us a dm with your email address so
# Question:  @Ask_Spectrum I can DM you but it won't make much difference when your website still says there's an outage in my area. Any updates on that?
#
# Expected:  <SOS> @129667 To check on the status of the outage Jessica, would you please provide your zip code. ^JJS <EOS>
#
# Given:
# i am sorry to hear about the service issues please dm us your account number and phone number so
# Question:  @Delta Your website comment form makes return trip a required field set. That's a problem for asking questions about 1-way flights.
#
# Expected:  <SOS> @116648 Is this in our Comments/Complaints section? *HKC <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @GWRHelp poor cs Jason Ness Manager! please respond to my query you keep breaking your promises
#
# Expected:  <SOS> @132688 Hi Sarah. What is this in relation to please? Did you receive an email informing you a cheque will be sent? Natalie <EOS>
#
# Given:
# hi there sorry for the delay this morning due to a fault with the signalling system is this is
# Question:  @AppleSupport You guys over charged me on iTunes @AppleSupport and I want my money back I’m really upset
#
# Expected:  <SOS> @123826 We completely understand and want to help. Please reach out to our iTunes Support team directly here: URL_POSITION <EOS>
#
# Given:
# we'd like to help with your service send us a dm with your email address so we can assist
# Question:  Nothing like paying @115821 for prime to get free quick shipping to be told the one thing I order per 6 months won't be on time lol
#
# Expected:  <SOS> @120403 Sorry to hear this. Has any reason been given for the delay? ^KM <EOS>
#
# Given:
# thanks for the shout out to us if you need anything else we can help with anything else please
# Question:  Just returned from Edinburgh on @British_Airways awful late there and stuck on plan on return. @120200 better every time.
#
# Expected:  <SOS> @120499 Oh we're sorry to hear this, Peter. We hope it didn't disrupt your plans. ^Alex <EOS>
#
# Given:
# hey there we don't have any info on this and be sure to share your feedback with the relevant
# Question:  @Ask_Spectrum Any outages in North Hollywood? All services are down here.
#
# Expected:  <SOS> @126194 I can look into the service impairments. Please DM your account number and service address. ^SS <EOS>
#
# Given:
# i am sorry to hear that please send us a dm with your email address so we can
# Question:  @SpotifyCares Al necessary updates done. Empty cache done... web based spotify is faster. But I think my Spotify Premium deserves to be fast.
#
# Expected:  <SOS> @128142 Thanks for letting us know. When did this start happening? Does logging out and back in help? You can also try restarting the app /CB <EOS>
#
# Given:
# we know how important to be sure to share your feedback with our team here url position
# Question:  @SouthwestAir We finally took off at noon and @SouthwestAir gave every single passenger a voucher. Thank you!!!  __EMOJI__folded_hands
#
# Expected:  <SOS> @126123 We apologize for the delay, and look forward to making more pleasant memories with you in the future. ^LC <EOS>
#
# Given:
# we're sorry to hear this was your experience with us we hope you have a great flight lindy
# Question:  Why does @115940 have such a hard time with live events and ads. Fix your goddamned system or I’m gone. The World Series is painful with you.
#
# Expected:  <SOS> @117876 Sorry to hear about this! Which device are you on? If you try a quick device+modem/router reboot, any change? <EOS>
#
# Given:
# hi there sorry to hear that please send us a dm with your email address so we can follow
# Question:  @TMobileHelp Oh thanks. I never received it. All I have is a survey invitation.
#
# Expected:  <SOS> @140115 Oh that's strange! Not a worry,  I will send you our DM again and let me know if you don't get this. :) *JenniferJackson <EOS>
#
# Given:
# i can help with your internet service concern please dm your account number and phone number so i can
# Question:  @AmazonHelp I have asked the customer care exec on phone to cancel the order. Don't want to waste any more of my time on this.
#
# Expected:  <SOS> @118701 I'm sorry about the trouble Manak. Kindly reply to the email sent by our team for further assistance. ^GD <EOS>
#
# Given:
# we don't have any info on this and we're here for you and we'll get back to you soon
# Question:  Absolutely disgraceful ‘service’ AGAIN from @GWRHelp can’t even be bothered to roster their staff properly, to cover their timetable. They’re more than happy however, to take my fares to pay for a ‘service’ they won’t provide. URL_POSITION
#
# Expected:  <SOS> @137816 Hi James. Sorry for the cancellation. What journey are you making? Lewis <EOS>
#
# Given:
# hi apologies for the delay this morning our website are you travelling on please rach
# Question:  @Delta your basic economy tickets are a joke. They are not cheaper than other airlines and you offer no way to upgrade them. I was trying to make my connection but not sure if I will #deltaistheworst #notflyingthemagain #missingchristmas
#
# Expected:  <SOS> @137400 Hi, Juli. We introduced the Basic Economy fare in order to provide more competitive pricing. The Basic Economy fare is clearly defined as a restrictive ticket. Therefore, changes are not permitted under voluntary changes. However, I will be happy to review your... 1/2 <EOS>
#
# Given:
# sorry to hear that please check your dm's for more instructions
# Question:  @VirginTrains It was supposed to be 10.55 from York to Edinburgh - we are now having to wait until 11.53 for the next (also delayed) train
#
# Expected:  <SOS> @132794 Looks as though you are travelling with @120576 today and therefore they would be best to advise. ^BT <EOS>
#
# Given:
# we're sorry to hear this was your experience with us we hope you have a great flight lindy
# Question:  @118954 No internet for two days now! Thanks @116136! Only internet provider where I live!
#
# Expected:  <SOS> @118953 Hello, will you please DM me your account number so I can look into this for you? -Jim <EOS>
#
# Given:
# i apologize for the troubles with your internet service can you please dm your account number and phone number
# Question:  @115888 In other news should probs upgrade from shitty 12GB package
#
# Expected:  <SOS> @116374 Hey Katie, thanks for the feedback – we appreciate it! We’ll get this passed onto the right team  __EMOJI__green_heart /CG <EOS>
#
# Given:
# hi there sorry for the delay this morning our team will be able to assist you onboard soon mk
# Question:  @XboxSupport Hi, I have a free MC for Windows 10 gift code, thanksto mojang account &amp; when I want to activate the product, it does not work __EMOJI__loudly_crying_face
#
# Expected:  <SOS> @130426 via DM: URL_POSITION so we can take a look? Have you tried these steps: URL_POSITION ?  2 ^ZM <EOS>
#
# Given:
# hey there please send us a dm with your email address so we can connect
# Question:  WARNING ! Do not buy @Tesco ripped jeans ! I wore them once and now the ‘hole’ on my knee is literally split to the zip ! #WasteOfMoney
#
# Expected:  <SOS> @128085 Please can you return the jeans and your receipt back to my colleagues instore who will be able to help you further. TY - Jayne 2/2 <EOS>
#
# Given:
# hi there please send us a dm with your email address so we can further assist you ls
# Question:  @115913 Question for you. What Black Friday deals on phones will T-Mobile offer? Because I love my Note 5 but want/need to upgrade!!!
#
# Expected:  <SOS> @119484 @115913 I love this time of year for great deals! We have a list of current offers here URL_POSITION I’d suggest keeping an eye here URL_POSITION for anything new that might come along. URL_POSITION *BarbPelotte <EOS>
#
# Given:
# 115913 we want to help with your service issues please dm us your account number and phone number so
# Question:  @XboxSupport Makes no difference I still got hacked
#
# ...
#
# Given:
# hi there we can help you with the store you can find the following link url position
# Question:  @sprintcare Well how come there are people on here who’s have shipped already?
#
# Expected:  <SOS> @117590 Not all order are shipped at the same time, however, they will be fulfilled. We will appreciate your patience. -JR <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  When your @SouthwestAir flight attendants refuse to help you find a seat and put your suitcase in the overhead bin despite having a broken shoulder and arm restricted to a sling. Great customer service.  __EMOJI__call_me_hand __EMOJI__medium-light_skin_tone
#
# Expected:  <SOS> @154355 We're sorry for any frustration with this situation, Jessica. While our Crew Members are not required to lift carryon bags due to health concerns, we apologize for any inconvenience this caused. We appreciate your feedback on this matter &amp; have taken your concerns to Heart. ^SL <EOS>
#
# Given:
# hi sorry for the delay this morning our team will be able to assist you onboard soon mk
# Question:  @115888 @SpotifyCares
#
# Expected:  <SOS> @129423 Hey Jack! You can let us know here. What's happening exactly? Can you tell us more info about it? /JE <EOS>
#
# Given:
# hey there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @Ask_Spectrum no #internet in #Dallas, TX. Is there an #outrage? Thank you
#
# Expected:  <SOS> @135151 My apologies for the service interruption.  Please follow/DM your service phone number and I would be happy to look into this for you. ^JK <EOS>
#
# Given:
# we have sent you a dm with your account's email address we'll take a look backstage nq url position
# Question:  @SpotifyCares Ok thx for thr explanation!
#
# Expected:  <SOS> @135366 No worries at all! For anything else, we're just a tweet away /JP <EOS>
#
# Given:
# hey there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @SpotifyCares URL_POSITION I cannot even find it on the app anymore.  I'm set to United States.
#
# Expected:  <SOS> @129236 Thanks. Sometimes content gets temporarily removed because of licensing changes. Hopefully we'll have it available again soon! /JP <EOS>
#
# Given:
# hey there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @sainsburys Hi, yes we have tried to contact them but had no response :(
#
# Expected:  <SOS> @125254 ...They will get back in touch with you as soon as possible.  You can find address details using the link, URL_POSITION. Aisha <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  .@SouthwestAir always keeps theirs passengers entertained no matter how busy they are  __EMOJI__slightly_smiling_face Up next #Nashville
#
# Expected:  <SOS> @139733 We aim to please! Thanks for the sweet tweet, Christine. ^NA <EOS>
#
# Given:
# we're sorry to hear this was your experience with us we hope you have a great flight lindy
# Question:  Interacted with one of the rudest flight attendants on @AmericanAir flight 1305 from ORD to SLC. Be patient, she's only 4. #flydeltainstead
#
# Expected:  <SOS> @117169 Oh my, we'd like to have more details about what happened. We always expect our team to treat our customers courteously and friendly. <EOS>
#
# Given:
# hi there we don't have any info on this and be sure to share your feedback on the
# Question:  @Ask_Spectrum Then I’d like to know why I’m paying for 300 Mbps down and only get 220 AT BEST
#
# Expected:  <SOS> @156873 Please DM us your account number or phone number so we can assist you. ^TZ <EOS>
#
# Given:
# i am sorry to hear about your internet service please dm your account number and phone number so we
# Question:  @comcastcares The @116136 lady on the phone right now is nice and yes, I will be putting these conversations on the internet.
#
# Expected:  <SOS> @124518 I'm happy to hear you are being assisted. If you need anything else please let me know, we're here 24/7. -BB <EOS>
#
# Given:
# i can help with your internet service concern please dm your account number and phone number so i can
# Question:  @GWRHelp Ok thanks for your help
#
# Expected:  <SOS> @134104 No problem. Have a nice evening - Josh <EOS>
#
# Given:
# hi there can you confirm the store you bought this from steven
# Question:  @sainsburys Thank you
#
# Expected:  <SOS> @140776 You're welcome! Marc <EOS>
#
# Given:
# that's concerning please let us know if you need any assistance please let us know if you need anything
# Question:  @118730 Dose Uber Eats need Full G  license ?
#
# Expected:  <SOS> @120789 Here to help! Send us a note here, URL_POSITION, and our team will follow up. <EOS>
#
# Given:
# hey there we'd like to help with your internet service please dm your account number and phone number so
# Question:  @116381 Hey hey! Thanks for reaching out! @SpotifyCares, could you help out with Pascal's payment update?
#
# Expected:  <SOS> @116380 @116381 Hey Pazcal! Could you send us a DM with your account's email address? We'll take a look backstage /MJ URL_POSITION <EOS>
#
# Given:
# hey there we can help you with today please let us know if you need anything else we can
# Question:  Unicorn! A @southwestair flight where everyone gets a row! @52896 @52897 set up camp and will hand out candy. #improv URL_POSITION
#
# Expected:  <SOS> @118775 @118776 Why be anything else when you can be a unicorn? Glad y'all could sit back and relax. See you again soon! ^SL <EOS>
#
# Given:
# we can help with your internet service concern please dm your account number and phone number so i can
# Question:  Wonder how long will it take for the morons at @115888 to update their app for the iPhone X, knowing that they were too proud of themselves to make an Apple Watch app.
# @SpotifyCares my ass
#
# Expected:  <SOS> @122735 Hey, we're here to help! Can you let us know what's happening exactly? We'll see what we can suggest /KM <EOS>
#
# Given:
# hi there i am sorry to hear this please dm your confirmation number and we'll take a look at
# Question:  @AmazonHelp sent twice. Ask me if something else you need.
#
# Expected:  <SOS> @120324 I appreciate your understanding in this regard. We've received your details and we'll get back to you at the earliest. ^SC <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @VirginTrains When your train manager (London to Glasgow) says we've stopped because the train in front is "testing the track"...? URL_POSITION
#
# Expected:  <SOS> @139752 We have to make sure it's working Ron ;). ^PA <EOS>
#
# Given:
# hi sorry for the delay this morning due to a fault with the signalling system is there for
# Question:  @Delta between a dent in a #plane, a missing part, #flight attendant issues, now an #engine that won’t start. Past 2 weeks = 15hrs in delays. I’m getting so sick of flying with you. Only so many “sorry for trouble” someone can take before switching #airlines.
#
# Expected:  <SOS> @135900 Hi Royce, we do apologize for the delays. It is never our goal to let you down. *AMS <EOS>
#
# Given:
# hey there can you dm us your account's email address or username we'll take a look backstage nq url
# Question:  @115900 getting Twitter via wifi, but Ethernet gives me dns error. ?
#
# Expected:  <SOS> @129245 I am happy to look into this for you. Can you send a DM with your address and phone number, so I can locate your account and assist? - Noah <EOS>
#
# Given:
# hey there we want to make sure you are having issues with your internet please dm us your phone
# Question:  @XboxSupport I’ve tried the steps I think apply hopefully it doesn’t do it again
#
# Expected:  <SOS> @129935 Just to clarify, is this issue still occurring?  ^JA <EOS>
#
# Given:
# hey there we don't have any info on this and be sure to share your feedback with the relevant
# Question:  @VirginTrains please sort out your WiFi! It is a total waste of time trying to work on it at present. Hardly marketing for your broadband!
#
# Expected:  <SOS> @122533 What issues are you having Tom? ^PA <EOS>
#
# Given:
# sorry for the delay to our team can you please dm your confirmation number so we can take a
# Question:  @SouthwestAir Thanks! We got to LA in record time. Thanks for the free drinks and for getting us here safely. Happy Thanksgiving!
#
# Expected:  <SOS> @141364 We're glad you've had an enjoyable trip, Nick! We hope to see you guys again soon. ^KJ <EOS>
#
# Given:
# we're sorry to hear that please send us a note at url position so our team can connect
# Question:  @VirginTrains bizarre train swap at Stafford but well executed by the staff at the station and onboard the trains
#
# Expected:  <SOS> @133688 Thanks for the great feedback, Michael ^LC <EOS>
#
# Given:
# sorry to hear that please check your dm's for more instructions
# Question:  @XboxSupport For how long this is taking you would think that I am trying to download the entire PornHub database. Cmon' bois, this is just unacceptable. URL_POSITION
#
# Expected:  <SOS> @145189 Hi there! We recommend power cycling your router to get the fastest connection. Let us know if this issue persists. ^CO <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @SouthwestAir Ken and Ashley at Spokane were friendly, helpful, and awesome! Shoutout for good employees!
#
# Expected:  <SOS> @154360 That's what we like to hear, Aaron! We'd love to pass along the kudos. Can you send us a DM with your confirmation number? ^SF URL_POSITION <EOS>
#
# Given:
# i can help with your internet service concern please dm your account number and phone number so i can
# Question:  @sprintcare Thanks!
#
# Expected:  <SOS> @128974 You are most welcome! Thank you for choosing Sprint. -JC <EOS>
#
# Given:
# we want to help you out please send us a dm with your email address so we can follow
# Question:  I lose faith in humanity on days like this. My friend sends me a  __EMOJI__wrapped_gift from @115821 after a crappy week and I come home and it’s been stolen.
#
# Expected:  <SOS> @118921 I'm so sorry! We'd like to look into our available options. Please reach us here: URL_POSITION ^AG <EOS>
#
# Given:
# hey there we don't have any info on this and want to help please dm your account number and
# Question:  As @AmericanAir Executive Platinum I tweet to them often. They are an amazing team!  Immediate responses, incredibly helpful-invaluable resource to their fliers. URL_POSITION
#
# Expected:  <SOS> @121138 We appreciate the kudos, Julie. We're always here for you #TweetUsIfYouNeedUs! <EOS>
#
# Given:
# we know how important it is working to be the recipe and we appreciate your patience
# Question:  @XboxSupport been using 3 paddles on my elite controller, decided to go with all 4, and noticed the 4th is very loose, help?
#
# Expected:  <SOS> @129762 Hey there! Are you noticing any performance issues with the controller?  ^JA <EOS>
#
# Given:
# here to help send us a note at url position so our team can connect
# Question:  @XboxSupport Yeah, cool. What's the error code though? Is it just a made up one?
#
# Expected:  <SOS> @125840 Error codes pop up for different reasons. We can not speculate why. ^RM <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @Delta Hmm so much for the priority check-in benefit for Silvers. I'll ask an agent next time. Thanks!
#
# Expected:  <SOS> @133349 Hello. Very sorry. On behalf of TSL, you're welcome!  *ARD <EOS>
#
# Given:
# sorry to hear that please send us a dm with your email address so we can connect
# Question:  @AmericanAir Ok landed. What compensation can you provide for this 2.5 hour delay?
#
# Expected:  <SOS> @122510 We see your DM and will reply to your comment there. <EOS>
#
# Given:
# we're so sorry to hear that we can help with this please dm us your full name address and
# Question:  @XboxSupport I purchased a 12 month live pass and cancelled my subscription for monthly Xbox, I’ve just been charged a months fee?
#
# Expected:  <SOS> @152816 We'd be happy to help, but we could use more info. Could you follow &amp; DM @Xboxsupport with your Gamertag? ^EZ <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  I want to go see to @115725 and leave @115714 they are liars
#
# Expected:  <SOS> @116446 What have you feeling this way? We would love to assist you.-DD <EOS>
#
# Given:
# we have sent you a direct message via twitter with further instructions
# Question:  Solid @115873 drivers out here that drive around without their lights on! Not getting in that car, keep up the good work gang.
#
# Expected:  <SOS> @120479 We're here to help! Send us a DM with your email address so we can connect. <EOS>
#
# Given:
# we're here to help send us a note via url position so our team can connect
# Question:  @Tesco I'm in Greenock, and I've tried value stuff and it's not cheaper for nothing. Dreadful stuff.
#
# Expected:  <SOS> @117490 I'm sorry to hear we have no easy cook long grain rice Louise. I would like to register your comments for you, can you DM your full name and address? TY - Jayne <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  So uh @ChipotleTweets can we talk about why this is in a lid for a sec URL_POSITION
#
# Expected:  <SOS> @157284 It would seem as if the team ran out of bowls. What location is this from? -James <EOS>
#
# Given:
# we're sorry to hear that please send us a note at url position so our team can connect
# Question:  @sainsburys can you help me please? Can you check stocks in stores or do you have an alternative contact please? URL_POSITION
#
# Expected:  <SOS> @134173 Hi Melody, which stores would you like us check for you? Danny <EOS>
#
# Given:
# hi there can you dm us your account's email address we'll take a look backstage nq url position
# Question:  @comcastcares Am I️ the only one having issues in 95835 or is there a larger issue?
#
# Expected:  <SOS> @140145 Hi! I'd be happy to take a look. Can you please send us a DM with your account number or address? -EM <EOS>
#
# Given:
# i apologize for the inconvenience i will be happy to help can you dm us your full name address
# Question:  @sprintcare Your offer of 50% off on note 8 or s8 leases
#
# Expected:  <SOS> @148368 Thank you for confirming. This offer is available  for new and existing customers adding a new line of service. -AC <EOS>
#
# Given:
# hi there please check your dm's for more instructions
# Question:  @AskPlayStation hi, im member of ps asia, ive voted in ps awards 2017 &amp; i haven't got the special theme reward for participate. Please help
#
# Expected:  <SOS> @126907 Glad to help! We have sent you a Direct Message via Twitter with further instructions. <EOS>
#
# Given:
# hi there please send us a dm with your email address so we can connect
# Question:  @VirginTrains i am on the 21:10 train from London to preston, it has not left the station yet because of no driver. Why, this is preposterous.
#
# Expected:  <SOS> @141999 Due to flooding between Lancaster and Preston and a Points Failure at Birmingham New Street they drivers previous working was heavily delayed. He is required to take a personal needs break. We anticipate you will be on the move shortly. ^JH <EOS>
#
# Given:
# sorry to hear that please check your dm's for more instructions
# Question:  Thx for the $3 burrito, @ChipotleTweets
# Sincerely, the Pavek watermelon and a Wid-Hoe URL_POSITION
#
# Expected:  <SOS> @119830 Lookin' good! And I'm glad we could help. -Becky <EOS>
#
# Given:
# we don't have any info on this and we're here for you let us know if you need anything
# Question:  Im full. Thank you @ChipotleTweets  __EMOJI__face_blowing_a_kiss __EMOJI__face_blowing_a_kiss __EMOJI__face_blowing_a_kiss __EMOJI__raising_hands __EMOJI__medium_skin_tone
#
# Expected:  <SOS> @119926 We've got you, fam. -Becky <EOS>
#
# Given:
# sorry for the delay to our team to be professional and courteous to the recipe and we can help
