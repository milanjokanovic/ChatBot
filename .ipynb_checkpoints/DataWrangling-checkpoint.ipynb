# %%
import pandas as pd

data = pd.read_csv("dataset/twcs.csv")
data
# Out:
#          tweet_id       author_id  inbound                      created_at  \
# 0               1      sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2          115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3          115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4      sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5          115712     True  Tue Oct 31 21:49:35 +0000 2017
# 5               6      sprintcare    False  Tue Oct 31 21:46:24 +0000 2017
# 6               8          115712     True  Tue Oct 31 21:45:10 +0000 2017
# 7              11      sprintcare    False  Tue Oct 31 22:10:35 +0000 2017
# 8              12          115713     True  Tue Oct 31 22:04:47 +0000 2017
# 9              15      sprintcare    False  Tue Oct 31 20:03:31 +0000 2017
# 10             16          115713     True  Tue Oct 31 20:00:43 +0000 2017
# ...

# %%
usedData = data.loc[(data['author_id'] == "AppleSupport") | (data['author_id'] == "AmazonHelp")]
usedData
# Out:
#          tweet_id     author_id  inbound                      created_at  \
# 181           269    AmazonHelp    False  Wed Nov 22 09:23:01 +0000 2017
# 184           273    AmazonHelp    False  Wed Nov 22 09:40:27 +0000 2017
# 186           275    AmazonHelp    False  Wed Nov 22 10:06:26 +0000 2017
# 234           324    AmazonHelp    False  Wed Nov 22 09:06:00 +0000 2017
# 321           615    AmazonHelp    False  Tue Oct 31 22:29:00 +0000 2017
# 323           618    AmazonHelp    False  Tue Oct 31 23:28:00 +0000 2017
# 326           620    AmazonHelp    False  Tue Oct 31 22:28:34 +0000 2017
# 328           622    AmazonHelp    False  Tue Oct 31 22:28:00 +0000 2017
# 330           625    AmazonHelp    False  Tue Oct 31 22:34:32 +0000 2017
# 332           626    AmazonHelp    False  Tue Oct 31 22:28:00 +0000 2017
# 334           629    AmazonHelp    False  Wed Nov 01 12:53:34 +0000 2017
# 337           631    AmazonHelp    False  Tue Oct 31 22:27:00 +0000 2017
# ...

# %%
companyData = data.loc[(data['author_id'].astype(str).str[0].str.match("\w(?<![\d_])"))]
selected_companies = companyData['author_id'].value_counts()[0:20]
company_list = list(selected_companies.keys())
data_for_use = data[(data['author_id'].isin(company_list) | data['text'].isin(company_list))]
#data_for_use['text'].str.split(' ').str[0]
#data_for_use['author_id'][73]
data_for_use
# Out:
#          tweet_id        author_id  inbound                      created_at  \
# 0               1       sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 3               4       sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 5               6       sprintcare    False  Tue Oct 31 21:46:24 +0000 2017
# 7              11       sprintcare    False  Tue Oct 31 22:10:35 +0000 2017
# 9              15       sprintcare    False  Tue Oct 31 20:03:31 +0000 2017
# 11             17       sprintcare    False  Tue Oct 31 19:59:13 +0000 2017
# 13             19       sprintcare    False  Tue Oct 31 22:10:10 +0000 2017
# 15             21     Ask_Spectrum    False  Tue Oct 31 22:14:37 +0000 2017
# 17             25     Ask_Spectrum    False  Tue Oct 31 22:18:28 +0000 2017
# 19             27     Ask_Spectrum    False  Tue Oct 31 22:21:26 +0000 2017
# 22             28     Ask_Spectrum    False  Tue Oct 31 22:05:37 +0000 2017
# ...

# %%
from langdetect import detect

data[detect(data['text'].str()) != 'en']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-79c3660d55f5> in <module>
#       1 from langdetect import detect
#       2
# ----> 3 data[detect(data['text'].str()) != 'en']
#
# TypeError: 'StringMethods' object is not callable
